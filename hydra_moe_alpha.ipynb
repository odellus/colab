# %% [markdown]
# <a href="https://colab.research.google.com/github/odellus/colab/blob/main/hydra_moe_alpha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Hydra-MoE Alpha (Inference)
#
# This is an example of using the Hydra-MoE repo for inference. It uses `inference.py` to launch an interactive chat session with our llama-MoE-7b model.
#
# NOTE: if inference takes a while you can run the demo with less experts by going into hydra_moe/router and editing the cluster_nums variable
#
# github link: https://github.com/SkunkworksAI/hydra-moe
# discord link: https://discord.gg/M3U7KZBT
#
# notebook by sumo43

# %%
# setup
! git clone https://github.com/SkunkworksAI/hydra-moe.git
#! cd hydra-moe
! pip3 install huggingface-hub
# Out:
# Cloning into 'hydra-moe'...
# remote: Enumerating objects: 658, done.
# remote: Counting objects: 100% (224/224), done.
# remote: Compressing objects: 100% (137/137), done.
# remote: Total 658 (delta 133), reused 154 (delta 85), pack-reused 434
# Receiving objects: 100% (658/658), 35.16 MiB | 22.45 MiB/s, done.
# Resolving deltas: 100% (387/387), done.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 6.3 MB/s eta 0:00:00
# ...

# %%
# login with huggingface
from huggingface_hub import notebook_login

notebook_login()

# %%
# %cd hydra-moe
! bash setup_moe.sh
# Out:
# /content/hydra-moe
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.9/91.9 MB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 79.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 9.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 27.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 11.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 67.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 90.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 11.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
# edit the config here. you can change the base model, adapter dir, and lora params

CONFIG = """model_name_or_path: "NousResearch/Nous-Hermes-llama-2-7b"
use_auth: true
output_dir: "./output"
logging_steps: 10
save_strategy: "steps"
data_seed: 42
save_steps: 500
save_total_limit: 40
evaluation_strategy: "steps"
eval_dataset_size: 1024
max_eval_samples: 1000
per_device_eval_batch_size: 1
max_new_tokens: 320
dataloader_num_workers: 1
group_by_length: true
logging_strategy: "steps"
remove_unused_columns: false
do_train: true
do_eval: true
do_mmlu_eval: true
lora_r: 64
lora_alpha: 16
lora_modules: "all"
double_quant: true
quant_type: "nf4"
bits: 4
warmup_ratio: 0.03
lr_scheduler_type: "constant"
gradient_checkpointing: true
dataset: "oasst1"
source_max_len: 16
target_max_len: 512
per_device_train_batch_size: 1
gradient_accumulation_steps: 16
max_steps: 1875
eval_steps: 187
learning_rate: 0.0002
adam_beta2: 0.999
max_grad_norm: 0.3
lora_dropout: 0.1
weight_decay: 0.0
seed: 0
max_memory: 40000
"""

with open('configs/colab_config.yaml', 'w') as f:
    f.write(CONFIG)

# !cat configs/colab_config.yaml
# Out:
# model_name_or_path: "NousResearch/Nous-Hermes-llama-2-7b"
# use_auth: true
# output_dir: "./output"
# logging_steps: 10
# save_strategy: "steps"
# data_seed: 42
# save_steps: 500
# save_total_limit: 40
# evaluation_strategy: "steps"
# eval_dataset_size: 1024
# max_eval_samples: 1000
# per_device_eval_batch_size: 1
# max_new_tokens: 320
# dataloader_num_workers: 1
# group_by_length: true
# logging_strategy: "steps"
# remove_unused_columns: false
# do_train: true
# do_eval: true
# do_mmlu_eval: true
# lora_r: 64
# lora_alpha: 16
# lora_modules: "all"
# double_quant: true
# quant_type: "nf4"
# bits: 4
# warmup_ratio: 0.03
# lr_scheduler_type: "constant"
# gradient_checkpointing: true
# dataset: "oasst1"
# source_max_len: 16
# target_max_len: 512
# per_device_train_batch_size: 1
# gradient_accumulation_steps: 16
# max_steps: 1875
# eval_steps: 187
# learning_rate: 0.0002
# adam_beta2: 0.999
# max_grad_norm: 0.3
# lora_dropout: 0.1
# weight_decay: 0.0
# seed: 0
# max_memory: 40000

# %%
# run inference
# %cd hydra-moe
# !python3 main.py --inference --config configs/colab_config.yaml
# Out:
# [Errno 2] No such file or directory: 'hydra-moe'
# /content/hydra-moe
#
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please run
#
# python -m bitsandbytes
#
#  and submit this information together with your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# ...
# bin /usr/local/lib/python3.10/dist-packages/bitsandbytes/libbitsandbytes_cuda118.so
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: /usr/lib64-nvidia did not contain ['libcudart.so', 'libcudart.so.11.0', 'libcudart.so.12.0'] as expected! Searching further paths...
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/sys/fs/cgroup/memory.events /var/colab/cgroup/jupyter-children/memory.events')}
#   warn(msg)
# ...
